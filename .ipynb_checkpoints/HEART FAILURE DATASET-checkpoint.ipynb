# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Santhosh\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_23184\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv(r'D:\datascience\assignments\heart_failure_clinical_records_dataset.csv')

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df.shape
# Out:
# (299, 13)

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
# summary of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
# descriptive summary of the data
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
df['DEATH_EVENT'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
# missing values in the dataset
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
# Duplicate records
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 294    False
# 295    False
# 296    False
# 297    False
# 298    False
# Length: 299, dtype: bool

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [age, anaemia, creatinine_phosphokinase, diabetes, ejection_fraction, high_blood_pressure, platelets, serum_creatinine, serum_sodium, sex, smoking, time, DEATH_EVENT]
# Index: []

# %%
df.corr()
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.088006                 -0.081584
# anaemia                   0.088006  1.000000                 -0.190741
# creatinine_phosphokinase -0.081584 -0.190741                  1.000000
# diabetes                 -0.101012 -0.012729                 -0.009639
# ejection_fraction         0.060098  0.031557                 -0.044080
# high_blood_pressure       0.093289  0.038182                 -0.070590
# platelets                -0.052354 -0.043786                  0.024463
# serum_creatinine          0.159187  0.052174                 -0.016408
# serum_sodium             -0.045966  0.041882                  0.059550
# sex                       0.065430 -0.094769                  0.079791
# smoking                   0.018668 -0.107290                  0.002421
# time                     -0.224068 -0.141414                 -0.009346
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# 1. What is the distribution of age among heart failure patients in the dataset
plt.figure(figsize=(8,6))
sns.distplot(df['age'],kde=True)
plt.title("Age Distribution")
plt.xlabel('age')
plt.show()
# Out:
# C:\Users\Santhosh\AppData\Local\Temp\ipykernel_23184\1236280050.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'],kde=True)
# C:\Users\Santhosh\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 2. How does the death rate vary with age
sns.violinplot(data=df,x='DEATH_EVENT',y='age')
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='age'>

# %%
# 2. How does the death rate vary with age
sns.histplot(data=df,x='DEATH_EVENT',y='age')
# Out:
# C:\Users\Santhosh\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Santhosh\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='DEATH_EVENT', ylabel='age'>

# %%
# 3. What is the percentage of male and female patients in the dataset
df['sex'].value_counts(normalize=True)
# Out:
# sex
# 1    0.648829
# 0    0.351171
# Name: proportion, dtype: float64

# %%
# 4. How does the platelet count vary among different age groups
sns.histplot(data=df,x='age',y='platelets')
# Out:
# C:\Users\Santhosh\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Santhosh\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='age', ylabel='platelets'>

# %%
#5 Is there correlation  between  creatinine  and sodium levels  in the blood
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)

# ans: yes the correlation is -0.19
# Out:
# <Axes: >

# %%
sns.countplot(x=df['sex'])
plt.xticks([0,1],['Female','Male'])
plt.show()

# %%
# 6 how does  the prevalence  of high blood pressure differ betwen  male and femal patients
sns.barplot(x='sex',y='high_blood_pressure',data=df)
plt.xticks([1,0],['Male','Female'])
# Out:
# ([<matplotlib.axis.XTick at 0x24dc0328400>,
# ...
#  [Text(1, 0, 'Male'), Text(0, 0, 'Female')])

# %%
# 6. how does  the prevalence  of high blood pressure differ betwen  male and femal patients
sns.countplot(x='sex',hue="high_blood_pressure",data=df)
plt.xticks([1,0],['Male','Female'])
plt.legend(labels=['No Disease','Disease'])
plt.show()

# %%
#7 what is relationship between smoking habits and the occurence of heart failure?
sns.histplot(data=df,x='smoking')
# Out:
# C:\Users\Santhosh\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='smoking', ylabel='Count'>

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
# 8 Are there any noticeabel patterens in the distribtuion of death events across different age groups?
sns.violinplot(data=df,x='DEATH_EVENT',y='age')
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='age'>

# %%
# 9 Is there any significant difference in ejection fraction between patients with and without diabiets


# no difference 
sns.barplot(data=df,x='diabetes',y='ejection_fraction')
# Out:
# <Axes: xlabel='diabetes', ylabel='ejection_fraction'>

# %%
# 10 How does the serum creatinine level vary between patients who survived and those who did not

sns.barplot(data=df,x='DEATH_EVENT',y='serum_creatinine')
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='serum_creatinine'>
